# %% [markdown]
# ## TSP Dantzig–Fulkerson–Johnson (DFJ) formulation

# %% [markdown]
# $ \text{Variables} $
#
# $x_{ij}={\begin{cases}1&{\text{the path goes from city }}i{\text{ to city }}j\\0&{\text{otherwise}}\end{cases}}$

# %% [markdown]
# \begin{equation*}
# \begin{aligned}
# & \underset{}{\text{minimize}}
# & & \sum_{i=1}^{n} \sum_{j=1, j\neq i}^{n} c_{ij} x_{ij} \\
# & \text{subject to}
# & & \sum_{j=1, j\neq i}^{n} x_{ij} = 1, \quad i = 1,\ldots,n, \\
# &
# & & \sum_{i=1, i\neq j}^{n} x_{ij} = 1, \quad j = 1,\ldots,n, \\
# &
# & & \sum_{i \in Q} \sum_{j\neq i, j \in Q,} x_{ij} \leq |Q| - 1, \quad \forall Q \subset{1,...,n},|Q| \ge 2 \\
# &
# & & x_{ij} \in \{0,1\}, \quad i,j = 1,\ldots,n, \, i\neq j, \\
# \end{aligned}
# \end{equation*}

# %%
########################################## Import library and model enviroment ############################################

from docplex.mp.model import Model
import networkx as nx   
import numpy as np
import matplotlib.pyplot as plt

mdl=Model('modelo')

# %%
def graphic(x,d,N):
    edges = []
    for i in N:
        for j in N:
            if i != j and x[i,j] > 0.5: # Este es un valor de tolerancia, puede ajustarse según la necesidad
                edges.append((i, j, d[i-1][j-1]))
    # Crear un grafo de NetworkX
    G = nx.Graph()
    for edge in edges:
        G.add_edge(edge[0], edge[1], weight=edge[2])

    plt.figure(figsize=(10, 10))
    # Dibujar el grafo
    pos = nx.spring_layout(G)
    nx.draw(G, pos, with_labels=True)
    labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
    # Mostrar el gráfico
    plt.show()

# %%
#Create a Random Matrix
C = np.random.randint(1, 100, size=(50, 50))
# A_i,i = 0
np.fill_diagonal(C, 0)

# %%
#Parameters
Nodes=len(C)

# %%
#Sets
N=[i for i in range(Nodes)]#i+1
#print(n)

# %%
#Index
Ind={(i,j) for i in N for j in N if i!=j}
#print(Ind)

# %%
#Variables
x=mdl.binary_var_dict(Ind, name='x')

# %%
mdl.minimize(mdl.sum(x[i,j]*C[i][j] for i in N for j in N if i!=j))

# %%
for i in N:
    mdl.add_constraint(mdl.sum(x[i,j] for j in N if i!=j)==1)

# %%
for j in N:
    mdl.add_constraint(mdl.sum(x[i,j] for i in N if i!=j)==1)

# %%
def find_subtours(sol):
    subtours = []
    remaining_nodes = list(range(len(sol))) #[i+1 for i in range(len(sol))]
    while len(remaining_nodes) > 0:
        subtour = []
        subtours.append(subtour)
        start = remaining_nodes[0]
        while True:
            subtour.append(start)
            if start in remaining_nodes:
                remaining_nodes.remove(start)
            next_node = next((j for (i, j), value in sol.items() if i == start and value > 0.5), None)
            if next_node is None or next_node not in remaining_nodes:
                break
            start = next_node
    return subtours

# %%
n=50
while True:
    solution = mdl.solve(log_output=True)
    if solution is None:
        print("No se encontró una solución")
        break
    sol = solution.get_value_dict(x, keep_zeros=False)
    subtours = find_subtours(sol)
    print("El subtour es...",subtours)
    if len(subtours) > 1:
        for subtour in subtours:
            if len(subtour) < n:
                mdl.add_constraint(mdl.sum(x[i, j] for i in subtour for j in subtour if i != j) <= len(subtour) - 1)
                

    else:
        break

print(solution)

solution = mdl.solve(log_output=True)
valor_objetivo = mdl.solution.get_objective_value()
x=solution.get_value_dict(x, keep_zeros=True, precision=1)


graphic(x,C,N)

print("Objective Value:",valor_objetivo)
# Out:
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_RandomSeed                              201903125
# Found incumbent of value 2258.000000 after 0.00 sec. (0.17 ticks)
# Found incumbent of value 360.000000 after 0.00 sec. (0.24 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 100 rows, 2450 columns, and 4900 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (3.13 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 100 rows, 2450 columns, and 4900 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (3.61 ticks)
# Probing time = 0.00 sec. (2.94 ticks)
# Clique table members: 100.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.00 sec. (1.41 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          360.0000        0.0000           100.00%
# *     0+    0                          329.0000        0.0000           100.00%
# *     0+    0                          280.0000        0.0000           100.00%
# *     0+    0                          276.0000        0.0000           100.00%
# *     0     0      integral     0      173.0000      173.0000       41    0.00%
# Elapsed time = 0.03 sec. (14.86 ticks, tree = 0.00 MB, solutions = 5)
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (15.02 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.05 sec. (15.02 ticks)
# El subtour es... [[0, 23, 14, 30, 31, 3, 48, 6, 11, 28, 37, 44, 4, 16, 18, 36, 9, 47, 40, 34, 27, 17, 8, 43, 25, 42, 20, 13, 10, 38], [1, 21, 22, 32, 19, 12, 39, 7, 2, 26, 49, 46, 33, 35, 41], [5, 15, 45, 29, 24]]
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_RandomSeed                              201903125
# 5 of 6 MIP starts provided solutions.
# MIP start 'm4' defined initial solution with objective 276.0000.
# Retaining values of one MIP start for possible repair.
# Tried aggregator 1 time.
# Reduced MIP has 103 rows, 2450 columns, and 6000 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (4.16 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 103 rows, 2450 columns, and 6000 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (4.70 ticks)
# Probing time = 0.02 sec. (2.88 ticks)
# Clique table members: 100.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.00 sec. (1.54 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          276.0000        0.0000           100.00%
# *     0+    0                          273.0000        0.0000           100.00%
# *     0+    0                          246.0000        0.0000           100.00%
# *     0     0      integral     0      174.0000      174.0000       45    0.00%
# Elapsed time = 0.08 sec. (18.82 ticks, tree = 0.00 MB, solutions = 8)
#
# Root node processing (before b&c):
#   Real time             =    0.08 sec. (19.03 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.08 sec. (19.03 ticks)
# El subtour es... [[0, 23, 14, 10, 38], [1, 30, 31, 3, 48, 6, 11, 27, 17, 8, 43, 25, 42, 20, 13, 36, 9, 47, 45, 29, 24, 5, 15, 28, 37, 44, 4, 16, 18, 2, 26, 49, 46, 33, 35, 41], [7, 40, 34, 21, 22, 32, 19, 12, 39]]
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_RandomSeed                              201903125
# 7 of 8 MIP starts provided solutions.
# MIP start 'm7' defined initial solution with objective 246.0000.
# Retaining values of one MIP start for possible repair.
# Tried aggregator 1 time.
# Reduced MIP has 106 rows, 2450 columns, and 7352 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (4.61 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 106 rows, 2450 columns, and 7352 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (5.22 ticks)
# Probing time = 0.00 sec. (2.86 ticks)
# Clique table members: 100.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (1.90 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          246.0000        0.0000           100.00%
# *     0+    0                          237.0000        0.0000           100.00%
# *     0+    0                          232.0000        0.0000           100.00%
#       0     0      174.0000    36      232.0000      174.0000       53   25.00%
# *     0+    0                          179.0000      174.0000             2.79%
# *     0     0      integral     0      174.0000      Cuts: 11       56    0.00%
#       0     0        cutoff            174.0000      174.0000       56    0.00%
# Elapsed time = 0.09 sec. (45.36 ticks, tree = 0.01 MB, solutions = 11)
#
# Cover cuts applied:  1
# Zero-half cuts applied:  1
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    0.11 sec. (45.66 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.11 sec. (45.66 ticks)
# El subtour es... [[0, 25, 42, 20, 13, 10, 32, 38], [1, 21, 22, 23, 14, 30, 31, 3, 48, 6, 11, 28, 37, 44, 5, 15, 45, 29, 24, 39, 7, 2, 26, 49, 46, 33, 35, 41], [4, 16, 18, 36, 9, 47, 40, 34, 27, 17, 8, 43], [12, 19]]
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_RandomSeed                              201903125
# 10 of 11 MIP starts provided solutions.
# MIP start 'm10' defined initial solution with objective 179.0000.
# Retaining values of one MIP start for possible repair.
# Tried aggregator 1 time.
# Reduced MIP has 110 rows, 2450 columns, and 8298 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (4.91 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 110 rows, 2450 columns, and 8298 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (5.56 ticks)
# Probing time = 0.00 sec. (2.86 ticks)
# Clique table members: 101.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (2.26 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          179.0000        0.0000           100.00%
#       0     0      174.1111    36      179.0000      174.1111       59    2.73%
# *     0+    0                          177.0000      174.1111             1.63%
# *     0+    0                          176.0000      174.1111             1.07%
#       0     0        cutoff            176.0000      174.1111       64    1.07%
# Elapsed time = 0.08 sec. (27.97 ticks, tree = 0.01 MB, solutions = 12)
# Root node processing (before b&c):
#   Real time             =    0.09 sec. (28.27 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (1.08 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.09 sec. (29.35 ticks)
# El subtour es... [[0, 25, 42, 20, 13, 38], [1, 30, 31, 3, 48, 6, 11, 27, 17, 8, 43, 4, 16, 18, 36, 9, 47, 45, 29, 24, 40, 34, 21, 22, 23, 14, 10, 32, 19, 12, 39, 7, 2, 26, 49, 46, 33, 35, 41], [5, 15, 28, 37, 44]]
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_RandomSeed                              201903125
# 11 of 12 MIP starts provided solutions.
# MIP start 'm11' defined initial solution with objective 177.0000.
# Retaining values of one MIP start for possible repair.
# Tried aggregator 1 time.
# Reduced MIP has 113 rows, 2450 columns, and 9830 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.03 sec. (5.45 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 113 rows, 2450 columns, and 9830 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (6.18 ticks)
# Probing time = 0.00 sec. (2.88 ticks)
# Clique table members: 101.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.00 sec. (2.24 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          177.0000        0.0000           100.00%
#       0     0      174.1111    36      177.0000      174.1111       60    1.63%
#       0     0      175.0000    36      177.0000      Cuts: 11       66    1.13%
#       0     0      175.3333    36      177.0000      Cuts: 11       77    0.94%
# *     0+    0                          176.0000      175.3333             0.38%
#       0     0        cutoff            176.0000      176.0000       77    0.00%
# Elapsed time = 0.16 sec. (71.43 ticks, tree = 0.01 MB, solutions = 12)
#
# Zero-half cuts applied:  1
# Gomory fractional cuts applied:  2
#
# Root node processing (before b&c):
#   Real time             =    0.17 sec. (71.78 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.17 sec. (71.78 ticks)
# El subtour es... [[0, 23, 19, 12, 39, 7, 40, 34, 21, 22, 30, 31, 3, 48, 6, 11, 27, 17, 8, 43, 25, 42, 20, 13, 36, 9, 47, 45, 29, 24, 5, 15, 28, 37, 44, 4, 16, 18, 2, 26, 49, 46, 33, 35, 41, 1, 14, 10, 32, 38]]
# solution for: modelo
# objective: 176
# x_46_33=1
# x_22_30=1
# x_34_21=1
# x_38_0=1
# x_17_8=1
# x_39_7=1
# x_10_32=1
# x_30_31=1
# x_2_26=1
# x_40_34=1
# x_14_10=1
# x_35_41=1
# x_43_25=1
# x_20_13=1
# x_36_9=1
# x_18_2=1
# x_31_3=1
# x_29_24=1
# x_42_20=1
# x_23_19=1
# x_48_6=1
# x_21_22=1
# x_27_17=1
# x_45_29=1
# x_0_23=1
# x_11_27=1
# x_32_38=1
# x_24_5=1
# x_25_42=1
# x_15_28=1
# x_8_43=1
# x_16_18=1
# x_44_4=1
# x_37_44=1
# x_26_49=1
# x_41_1=1
# x_47_45=1
# x_3_48=1
# x_5_15=1
# x_28_37=1
# x_6_11=1
# x_7_40=1
# x_33_35=1
# x_4_16=1
# x_12_39=1
# x_49_46=1
# x_19_12=1
# x_1_14=1
# x_9_47=1
# x_13_36=1
#
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_RandomSeed                              201903125
# 12 of 12 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 176.0000.
# Tried aggregator 1 time.
# Reduced MIP has 113 rows, 2450 columns, and 9830 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (5.45 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 113 rows, 2450 columns, and 9830 nonzeros.
# Reduced MIP has 2450 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (6.18 ticks)
# Probing time = 0.00 sec. (2.88 ticks)
# Clique table members: 101.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (2.24 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          176.0000        0.0000           100.00%
#       0     0      174.1111    36      176.0000      174.1111       60    1.07%
#       0     0        cutoff            176.0000                     61    0.00%
# Elapsed time = 0.06 sec. (27.14 ticks, tree = 0.01 MB, solutions = 12)
#
# Root node processing (before b&c):
#   Real time             =    0.08 sec. (27.44 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.08 sec. (27.44 ticks)
# Objective Value: 176

# %% [markdown]
# $Literature$
#
# https://en.wikipedia.org/wiki/Travelling_salesman_problem#cite_note-19
